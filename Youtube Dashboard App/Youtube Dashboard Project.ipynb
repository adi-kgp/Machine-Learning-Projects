# %%
#import libraries
# !pip install streamlit
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import streamlit as st
from datetime import datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.1 MB 7.2 MB/s
# ...
#      |████████████████████████████████| 181 kB 63.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 63.3 MB/s
# ...
#      |████████████████████████████████| 235 kB 79.1 MB/s
# ...
#      |████████████████████████████████| 164 kB 78.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 51 kB 9.7 MB/s
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=d969995ff0ea3b32c2ea38c356f0098e3fd3c7cfc519e71084f99ec50bf8168d
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# ...

# %%
# load data
df_agg = pd.read_csv("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Youtube Dashboard App/youtube_data/Aggregated_Metrics_By_Video.csv").iloc[1:,:]
df_agg.head(2)
# Out:
#          Video                                        Video title  \
# 1  4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2  78LjdAAw0wA                  100K Channel Update + AMA Stream!
#
#   Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes  Likes  \
# 1         May 8, 2020               907    9583        942  46903
# 2        Nov 12, 2020               412       4          4    130
#
#    Sub­scribers lost  Sub­scribers gained  RPM (USD)  CPM (USD)  \
# 1                451                46904      6.353     12.835
# 2                 15                   12      2.668      6.259
#
#    Av­er­age per­cent­age viewed (%) Av­er­age view dur­a­tion    Views  \
# 1                              36.65                   0:03:09  1253559
# 2                               6.26                   0:05:14     2291
#
#    Watch time (hours)  Sub­scribers  Your es­tim­ated rev­en­ue (USD)  \
# 1          65850.7042         46453                          7959.533
# ...

# %%
df_agg_sub = pd.read_csv('/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Youtube Dashboard App/youtube_data/Aggregated_Metrics_By_Country_And_Subscriber_Status.csv')
df_agg_sub.head(2)
# Out:
#                                          Video Title External Video ID  \
# 0  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
#
#    Video Length                                    Thumbnail link  \
# 0            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 1            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
#
#   Country Code  Is Subscribed  Views  Video Likes Added  Video Dislikes Added  \
# 0           HK           True     23                  1                     0
# 1           ME           True      3                  0                     0
#
#    Video Likes Removed  User Subscriptions Added  User Subscriptions Removed  \
# 0                    0                         2                           0
# 1                    0                         0                           0
#
#    Average View Percentage  Average Watch Time  User Comments Added
# ...

# %%
df_comments = pd.read_csv("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Youtube Dashboard App/youtube_data/Aggregated_Metrics_By_Video.csv")
df_time = pd.read_csv("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Youtube Dashboard App/youtube_data/Video_Performance_Over_Time.csv")

# %%
# load data
df_agg.columns = ['Video', 'Video title', 'Video publish time', 'Comments added', 'Shares', 'Dislikes', 'Likes', 'Subscribers lost',
                  'Subscribers gained', 'RPM(USD)', 'CPM(USD)', 'Average % Viewed', 'Average view duration', 'Views', 'Watch time (hours)',
                  'Subscribers', 'Your estimated revenue (USD)', 'Impressions', 'Impressions ctr(%)']
df_agg['Video publish time'] = pd.to_datetime(df_agg['Video publish time'])
